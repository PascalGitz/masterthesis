# %%
import sympy as sp

# %%
tau, h, z, f_ct = sp.symbols('tau, h, z f_ct')
E, nu = sp.symbols('E, nu')
gamma = sp.Function('gamma')(z)

# %% [markdown]
# linearer Schubspannungsverlauf mit Maximum bei f_ct

# %%
rho_x, rho_y, n = sp.symbols('rho_x, rho_y, n')

# %% [markdown]
# $$
# \tau = G * \gamma
# $$

# %%
G = E / (2*(1+nu))
# G = (2 / E * (sp.sqrt((1+n*rho_x)*(1+n*rho_y) / (rho_x * rho_y) + n)))**-1
G
# Out:
# E/(2*nu + 2)

# %%
gamma_expr = z

# %%
expr_tau = G*gamma_expr

expr_tau = f_ct * z

sp.plot(expr_tau.subs({h:1, f_ct:2}), (z, -1, 1))

# %%
m_x = sp.integrate(expr_tau * z , (z, -h/2, h/2))
m_x
# Out:
# f_ct*h**3/12

# %%
q, x = sp.symbols('q, x')
EI, l, F = sp.symbols('EI, l, F')

# %%
M_x = -F*(l-x)

phi = sp.integrate(M_x, x)

w_x = sp.integrate(phi,x)

sp.plot(M_x.subs(F,1).subs(l,1), (x,0,1))
sp.plot(phi.subs(F,1).subs(l,1), (x,0,1))
sp.plot(w_x.subs(F,1).subs(l,1), (x,0,1))

# %%
phi
# Out:
# -F*l*x + F*x**2/2
